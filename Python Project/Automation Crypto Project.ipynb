# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '6bd6f28f-f87d-4a61-8e63-727ab72fa748',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-11-13T16:35:03.735Z', 'error_code': 0, 'error_message': None, 'elapsed': 117, 'credit_count': 1, 'notice': None, 'total_count': 8821}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10552, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19541375, 'total_supply': 19541375, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T16:34:00.000Z', 'quote': {'USD': {'price': 36953.50044186055, 'volume_24h': 16249704522.581396, 'volume_change_24h': 29.7242, 'percent_change_1h': 0.54849206, 'percent_change_24h': -0.56056474, 'percent_change_7d': 5.42510119, 'percent_change_30d': 37.29256996, 'percent_change_60d': 38.54892763, 'percent_change_90d': 26.11031771, 'market_cap': 722122209697.0627, 'market_cap_dominance': 50.7845, 'fully_diluted_market_cap': 776023509279.07, 'tvl': None, 'last_updated': '2023-11-13T16:34:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7772, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120260281.43503532, 'total_supply': 120260281.43503532, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T16:34:00.000Z', 'quote': {'USD': {'price': 2098.2924048744057, 'volume_24h': 12451997646.235634, 'volume_change_24h': 46.178, 'percent_change_1h': 0.43668279, 'percent_change_24h': 2.07131914, 'percent_change_7d': 10.5774677, 'percent_change_30d': 35.03896359, 'percent_change_60d': 28.42948721, 'percent_change_90d': 14.11587439, 'market_cap': 252341235143.1931, 'market_cap_dominance': 17.7458, 'fully_diluted_market_cap': 252341235143.19, 'tvl': None, 'last_updated': '2023-11-13T16:34:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 65622, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 86804455790.35953, 'total_supply': 90623656723.10593, 'plat ...

# %%
import pandas as pd 

pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# /var/folders/w1/9zgg66y549123s44_jjg_kww0000gn/T/ipykernel_4696/644439384.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7772
# 2     825  Tether USDt   USDT        tether             65622
# 3    1839          BNB    BNB           bnb              1757
# 4      52          XRP    XRP           xrp              1140
# 5    3408         USDC   USDC      usd-coin             14908
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               970
# 8      74     Dogecoin   DOGE      dogecoin               823
# 9    1958         TRON    TRX          tron               868
# 10   1975    Chainlink   LINK     chainlink              1429
# 11  11419      Toncoin    TON       toncoin               171
# 12   3890      Polygon  MATIC       polygon              1061
# 13   6636     Polkadot    DOT  polkadot-new               611
# 14   5805    Avalanche   AVAX     avalanche               551
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2017-09-20T00:00:00.000Z
# 11  2021-08-26T13:40:22.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 7   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...           NaN
# 10  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 11  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...           NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...  7.200000e+08
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.954129e+07  1.954129e+07            False       NaN         1
# 1         1.202603e+08  1.202603e+08             True       NaN         2
# 2         8.680446e+10  9.062366e+10             True       NaN         3
# 3         1.517016e+08  1.517016e+08            False       NaN         4
# 4         5.365277e+10  9.998824e+10            False       NaN         5
# 5         2.414343e+10  2.414343e+10            False       NaN         6
# 6         4.221648e+08  5.622911e+08             True       NaN         7
# 7         3.526851e+10  3.635027e+10            False       NaN         8
# 8         1.418137e+11  1.418137e+11             True       NaN         9
# 9         8.868725e+10  8.868728e+10             True       NaN        10
# 10        5.568500e+08  1.000000e+09            False       NaN        11
# 11        3.431892e+09  5.047559e+09             True       NaN        12
# 12        9.250320e+09  1.000000e+10            False       NaN        13
# 13        1.302643e+09  1.377015e+09             True       NaN        14
# 14        3.554276e+08  4.328037e+08            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                       7.165966e+10              7.866386e+09      None
# 10                               NaN                       NaN      None
# 11                      3.414167e+09              8.328206e+09      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-11-13T16:10:00.000Z     36887.343877          1.596001e+10
# 1   2023-11-13T16:10:00.000Z      2112.711049          1.215566e+10
# 2   2023-11-13T16:09:00.000Z         1.000402          4.136075e+10
# 3   2023-11-13T16:09:00.000Z       247.241236          8.160087e+08
# 4   2023-11-13T16:10:00.000Z         0.651621          1.124410e+09
# 5   2023-11-13T16:09:00.000Z         1.000246          4.847068e+09
# 6   2023-11-13T16:10:00.000Z        55.982838          2.713345e+09
# 7   2023-11-13T16:09:00.000Z         0.370964          3.938743e+08
# 8   2023-11-13T16:10:00.000Z         0.077382          7.204448e+08
# 9   2023-11-13T16:09:00.000Z         0.109774          2.713885e+08
# 10  2023-11-13T16:09:00.000Z        15.195080          8.598267e+08
# 11  2023-11-13T16:10:00.000Z         2.439309          5.408956e+07
# 12  2023-11-13T16:09:00.000Z         0.893694          9.764662e+08
# 13  2023-11-13T16:09:00.000Z         5.591829          3.151756e+08
# 14  2023-11-13T16:09:00.000Z        17.558161          8.886985e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       27.2323                     0.271014
# 1                       42.5722                     1.165296
# 2                       11.8545                    -0.007330
# 3                       -2.3675                     0.256022
# 4                       -1.6751                     0.207316
# 5                       32.8282                     0.017530
# 6                      -22.6641                    -0.300718
# 7                      -18.7498                     0.546359
# 8                      -18.2127                     0.421354
# 9                       17.0219                     0.166330
# 10                     -14.2741                     0.383704
# 11                     -11.1692                     0.436116
# 12                      52.1940                     0.944701
# 13                     -34.1280                     0.171042
# 14                     -30.2214                    -0.180916
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -0.698708                     5.078021
# 1                       2.731492                    10.968730
# 2                      -0.002292                    -0.001855
# 3                      -0.599640                    -1.715870
# 4                      -1.877326                    -9.116301
# 5                       0.037503                     0.023872
# 6                      -3.583985                    38.745131
# 7                      -3.901332                     5.021485
# 8                      -1.341760                     4.650984
# 9                       1.289848                    11.776817
# 10                     -4.535868                    19.927857
# 11                     -1.702489                     5.126904
# 12                      6.826628                    24.808160
# 13                     -2.917947                    14.581478
# 14                     -2.969857                    35.123803
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      36.922832                     38.318899
# 1                      35.664415                     29.379570
# 2                       0.033171                      0.014662
# 3                      19.537962                     15.994693
# 4                      33.654130                     33.678916
# 5                      -0.003648                      0.007373
# 6                     154.082007                    194.153230
# 7                      49.796438                     47.845749
# 8                      30.013271                     25.264925
# 9                      28.538247                     32.098789
# 10                    107.737886                    149.184012
# 11                     26.337268                     29.118054
# 12                     71.480054                     70.618238
# 13                     48.748173                     38.071320
# 14                     90.459549                     87.358353
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      25.934691          7.208262e+11
# 1                      14.971968          2.540752e+11
# 2                       0.185478          8.683931e+10
# 3                       3.455091          3.750688e+10
# 4                       4.302629          3.496127e+10
# 5                       0.021512          2.414937e+10
# 6                     126.640121          2.363398e+10
# 7                      28.729301          1.308334e+10
# 8                       5.004338          1.097384e+10
# 9                      42.350841          9.735578e+09
# 10                    108.630971          8.461380e+09
# 11                     64.835969          8.371444e+09
# 12                     34.704520          8.266952e+09
# 13                     12.987333          7.284155e+09
# 14                     43.452845          6.240654e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          50.8076                        7.746342e+11
# 1                          17.9150                        2.540752e+11
# 2                           6.1331                        9.066005e+10
# 3                           2.6451                        3.750688e+10
# 4                           2.4651                        6.516210e+10
# 5                           1.7056                        2.414937e+10
# 6                           1.6664                        3.147865e+10
# 7                           0.9240                        1.669337e+10
# 8                           0.7739                        1.097384e+10
# 9                           0.6876                        9.735581e+09
# 10                          0.5976                        1.519508e+10
# 11                          0.5901                        1.231255e+10
# 12                          0.5830                        8.936936e+09
# 13                          0.5141                        7.700031e+09
# 14                          0.4408                        1.264188e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 1           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 2           None  2023-11-13T16:09:00.000Z       1027.0      Ethereum
# 3           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 4           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 5           None  2023-11-13T16:09:00.000Z       1027.0      Ethereum
# 6           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 7           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 8           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 9           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 10          None  2023-11-13T16:09:00.000Z       1027.0      Ethereum
# 11          None  2023-11-13T16:10:00.000Z          NaN           NaN
# 12          None  2023-11-13T16:09:00.000Z          NaN           NaN
# 13          None  2023-11-13T16:09:00.000Z          NaN           NaN
# 14          None  2023-11-13T16:09:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-11-13 16:11:18.910441
# 1  2023-11-13 16:11:18.910441
# 2  2023-11-13 16:11:18.910441
# 3  2023-11-13 16:11:18.910441
# 4  2023-11-13 16:11:18.910441
# 5  2023-11-13 16:11:18.910441
# 6  2023-11-13 16:11:18.910441
# 7  2023-11-13 16:11:18.910441
# 8  2023-11-13 16:11:18.910441
# 9  2023-11-13 16:11:18.910441
# 10 2023-11-13 16:11:18.910441
# 11 2023-11-13 16:11:18.910441
# 12 2023-11-13 16:11:18.910441
# 13 2023-11-13 16:11:18.910441
# 14 2023-11-13 16:11:18.910441

# %% [markdown]
# # Automating the Data Pull

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '6bd6f28f-f87d-4a61-8e63-727ab72fa748',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    #df
    
    #Automating Data Pull to csv 
    #checks if there is a file in this name
    if not os.path.isfile(r'/Users/lumeenahoro/Downloads/PY/API.csv'):
        df.to_csv(r'/Users/lumeenahoro/Downloads/PY/API.csv',header='column_names')
    else:
        df.to_csv(r'/Users/lumeenahoro/Downloads/PY/API.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep 

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute 
exit()
# Out:
# {'status': {'timestamp': '2023-11-13T17:01:14.683Z', 'error_code': 0, 'error_message': None, 'elapsed': 33, 'credit_count': 1, 'notice': None, 'total_count': 8823}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10552, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19541375, 'total_supply': 19541375, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T17:00:00.000Z', 'quote': {'USD': {'price': 36870.15911304387, 'volume_24h': 16438059005.210453, 'volume_change_24h': 32.0691, 'percent_change_1h': 0.07035233, 'percent_change_24h': -0.6961574, 'percent_change_7d': 5.38897651, 'percent_change_30d': 36.91037353, 'percent_change_60d': 38.48025952, 'percent_change_90d': 26.06320941, 'market_cap': 720493605537.6576, 'market_cap_dominance': 50.9509, 'fully_diluted_market_cap': 774273341373.92, 'tvl': None, 'last_updated': '2023-11-13T17:00:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7772, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120260281.43503532, 'total_supply': 120260281.43503532, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T17:00:00.000Z', 'quote': {'USD': {'price': 2087.7778177423634, 'volume_24h': 12784605931.805523, 'volume_change_24h': 52.0376, 'percent_change_1h': -0.87600711, 'percent_change_24h': 1.75823491, 'percent_change_7d': 10.13800714, 'percent_change_30d': 34.17488444, 'percent_change_60d': 27.68228648, 'percent_change_90d': 13.7278373, 'market_cap': 251076747935.52048, 'market_cap_dominance': 17.7559, 'fully_diluted_market_cap': 251076747935.52, 'tvl': None, 'last_updated': '2023-11-13T17:00:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 65624, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 86804455790.35953, 'total_supply': 90623656723.10593, 'pla ...
# API Runner completed
# /var/folders/w1/9zgg66y549123s44_jjg_kww0000gn/T/ipykernel_4696/867350483.py:27: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2['timestamp'] = pd.to_datetime('now')
# {'status': {'timestamp': '2023-11-13T17:02:16.137Z', 'error_code': 0, 'error_message': None, 'elapsed': 706, 'credit_count': 1, 'notice': None, 'total_count': 8823}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10552, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate'], 'max_supply': 21000000, 'circulating_supply': 19541375, 'total_supply': 19541375, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T17:01:00.000Z', 'quote': {'USD': {'price': 36867.985656503435, 'volume_24h': 16442327998.183302, 'volume_change_24h': 32.2753, 'percent_change_1h': 0.01977916, 'percent_change_24h': -0.67142111, 'percent_change_7d': 5.39480967, 'percent_change_30d': 36.89923196, 'percent_change_60d': 38.48160215, 'percent_change_90d': 26.04988868, 'market_cap': 720451133208.3549, 'market_cap_dominance': 50.9479, 'fully_diluted_market_cap': 774227698786.57, 'tvl': None, 'last_updated': '2023-11-13T17:01:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 7772, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1', 'ftx-bankruptcy-estate'], 'max_supply': None, 'circulating_supply': 120260281.43503532, 'total_supply': 120260281.43503532, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-11-13T17:01:00.000Z', 'quote': {'USD': {'price': 2086.488698506996, 'volume_24h': 12788389652.179283, 'volume_change_24h': 52.6043, 'percent_change_1h': -1.02615355, 'percent_change_24h': 1.71329019, 'percent_change_7d': 10.07809182, 'percent_change_30d': 34.11696955, 'percent_change_60d': 27.64291375, 'percent_change_90d': 13.64949797, 'market_cap': 250921718093.4719, 'market_cap_dominance': 17.7449, 'fully_diluted_market_cap': 250921718093.47, 'tvl': None, 'last_updated': '2023-11-13T17:01:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 65624, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 86804455790.35953, 'total_supply': 90623656723.10593, 'p ...
# API Runner completed
# /var/folders/w1/9zgg66y549123s44_jjg_kww0000gn/T/ipykernel_4696/867350483.py:27: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2['timestamp'] = pd.to_datetime('now')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %% [markdown]
# # Transfroming Data

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7772
# 2     825  Tether USDt   USDT        tether             65622
# 3    1839          BNB    BNB           bnb              1757
# 4      52          XRP    XRP           xrp              1140
# 5    3408         USDC   USDC      usd-coin             14908
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               970
# 8      74     Dogecoin   DOGE      dogecoin               823
# 9    1958         TRON    TRX          tron               868
# 10   1975    Chainlink   LINK     chainlink              1429
# 11  11419      Toncoin    TON       toncoin               171
# 12   3890      Polygon  MATIC       polygon              1061
# 13   6636     Polkadot    DOT  polkadot-new               611
# 14   5805    Avalanche   AVAX     avalanche               551
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2017-09-20T00:00:00.000Z
# 11  2021-08-26T13:40:22.000Z
# 12  2019-04-28T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...                NaN
# 10  [platform, defi, oracles, smart-contracts, sub...   1000000000.00000
# 11  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                NaN
# 12  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19541287.00000     19541287.00000            False       NaN
# 1      120260281.43504    120260281.43504             True       NaN
# 2    86804455790.35953  90623656723.10593             True       NaN
# 3      151701553.62083    151701553.62083            False       NaN
# 4    53652766196.00000  99988240531.00000            False       NaN
# 5    24143428672.16486  24143428672.16486            False       NaN
# 6      422164754.62936    562291062.21795             True       NaN
# 7    35268510014.58100  36350273102.30800            False       NaN
# 8   141813726383.70517 141813726383.70517             True       NaN
# 9    88687254734.80621  88687284071.03496             True       NaN
# 10     556849970.45279   1000000000.00000            False       NaN
# 11    3431892087.62000   5047558528.00000             True       NaN
# 12    9250320053.92012  10000000000.00000            False       NaN
# 13    1302642656.79835   1377014667.79748             True       NaN
# 14     355427552.59410    432803732.59410            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                 71659659264.00000          7866385985.65787
# 10        11                               NaN                       NaN
# 11        12                  3414166606.00000          8328206468.64503
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-11-13T16:10:00.000Z      36887.34388     15960014080.16153
# 1       None  2023-11-13T16:10:00.000Z       2112.71105     12155656933.59401
# 2       None  2023-11-13T16:09:00.000Z          1.00040     41360751815.41595
# 3       None  2023-11-13T16:09:00.000Z        247.24124       816008693.92504
# 4       None  2023-11-13T16:10:00.000Z          0.65162      1124409532.39921
# 5       None  2023-11-13T16:09:00.000Z          1.00025      4847068342.04630
# 6       None  2023-11-13T16:10:00.000Z         55.98284      2713344605.94134
# 7       None  2023-11-13T16:09:00.000Z          0.37096       393874335.82211
# 8       None  2023-11-13T16:10:00.000Z          0.07738       720444750.27680
# 9       None  2023-11-13T16:09:00.000Z          0.10977       271388507.70053
# 10      None  2023-11-13T16:09:00.000Z         15.19508       859826661.63304
# 11      None  2023-11-13T16:10:00.000Z          2.43931        54089562.27549
# 12      None  2023-11-13T16:09:00.000Z          0.89369       976466203.73167
# 13      None  2023-11-13T16:09:00.000Z          5.59183       315175613.11395
# 14      None  2023-11-13T16:09:00.000Z         17.55816       888698524.95406
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      27.23230                      0.27101
# 1                      42.57220                      1.16530
# 2                      11.85450                     -0.00733
# 3                      -2.36750                      0.25602
# 4                      -1.67510                      0.20732
# 5                      32.82820                      0.01753
# 6                     -22.66410                     -0.30072
# 7                     -18.74980                      0.54636
# 8                     -18.21270                      0.42135
# 9                      17.02190                      0.16633
# 10                    -14.27410                      0.38370
# 11                    -11.16920                      0.43612
# 12                     52.19400                      0.94470
# 13                    -34.12800                      0.17104
# 14                    -30.22140                     -0.18092
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -0.69871                      5.07802
# 1                        2.73149                     10.96873
# 2                       -0.00229                     -0.00186
# 3                       -0.59964                     -1.71587
# 4                       -1.87733                     -9.11630
# 5                        0.03750                      0.02387
# 6                       -3.58398                     38.74513
# 7                       -3.90133                      5.02148
# 8                       -1.34176                      4.65098
# 9                        1.28985                     11.77682
# 10                      -4.53587                     19.92786
# 11                      -1.70249                      5.12690
# 12                       6.82663                     24.80816
# 13                      -2.91795                     14.58148
# 14                      -2.96986                     35.12380
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       36.92283                      38.31890
# 1                       35.66442                      29.37957
# 2                        0.03317                       0.01466
# 3                       19.53796                      15.99469
# 4                       33.65413                      33.67892
# 5                       -0.00365                       0.00737
# 6                      154.08201                     194.15323
# 7                       49.79644                      47.84575
# 8                       30.01327                      25.26493
# 9                       28.53825                      32.09879
# 10                     107.73789                     149.18401
# 11                      26.33727                      29.11805
# 12                      71.48005                      70.61824
# 13                      48.74817                      38.07132
# 14                      90.45955                      87.35835
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       25.93469    720826173371.08813
# 1                       14.97197    254075225343.85257
# 2                        0.18548     86839314420.57611
# 3                        3.45509     37506879616.76556
# 4                        4.30263     34961269143.45089
# 5                        0.02151     24149372948.59670
# 6                      126.64012     23633980900.56184
# 7                       28.72930     13083338107.23854
# 8                        5.00434     10973844264.16302
# 9                       42.35084      9735577658.58413
# 10                     108.63097      8461379585.04720
# 11                      64.83597      8371444391.02061
# 12                      34.70452      8266951953.64164
# 13                      12.98733      7284155257.57823
# 14                      43.45285      6240654285.85090
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         50.80760                  774634221420.16003
# 1                         17.91500                  254075225343.85001
# 2                          6.13310                   90660049054.70000
# 3                          2.64510                   37506879616.77000
# 4                          2.46510                   65162099966.54000
# 5                          1.70560                   24149372948.60000
# 6                          1.66640                   31478649222.35000
# 7                          0.92400                   16693367952.95000
# 8                          0.77390                   10973844264.16000
# 9                          0.68760                    9735580878.95000
# 10                         0.59760                   15195079525.94000
# 11                         0.59010                   12312553672.65000
# 12                         0.58300                    8936936133.51000
# 13                         0.51410                    7700030841.04000
# 14                         0.44080                   12641876109.54000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 1           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 2           None  2023-11-13T16:09:00.000Z   1027.00000      Ethereum
# 3           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 4           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 5           None  2023-11-13T16:09:00.000Z   1027.00000      Ethereum
# 6           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 7           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 8           None  2023-11-13T16:10:00.000Z          NaN           NaN
# 9           None  2023-11-13T16:09:00.000Z          NaN           NaN
# 10          None  2023-11-13T16:09:00.000Z   1027.00000      Ethereum
# 11          None  2023-11-13T16:10:00.000Z          NaN           NaN
# 12          None  2023-11-13T16:09:00.000Z          NaN           NaN
# 13          None  2023-11-13T16:09:00.000Z          NaN           NaN
# 14          None  2023-11-13T16:09:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-11-13 16:11:18.910441
# 1  2023-11-13 16:11:18.910441
# 2  2023-11-13 16:11:18.910441
# 3  2023-11-13 16:11:18.910441
# 4  2023-11-13 16:11:18.910441
# 5  2023-11-13 16:11:18.910441
# 6  2023-11-13 16:11:18.910441
# 7  2023-11-13 16:11:18.910441
# 8  2023-11-13 16:11:18.910441
# 9  2023-11-13 16:11:18.910441
# 10 2023-11-13 16:11:18.910441
# 11 2023-11-13 16:11:18.910441
# 12 2023-11-13 16:11:18.910441
# 13 2023-11-13 16:11:18.910441
# 14 2023-11-13 16:11:18.910441

# %%
df3 = df.groupby('name',sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.27101                      -0.69871
# Ethereum                         1.16530                       2.73149
# Tether USDt                     -0.00733                      -0.00229
# BNB                              0.25602                      -0.59964
# XRP                              0.20732                      -1.87733
# USDC                             0.01753                       0.03750
# Solana                          -0.30072                      -3.58398
# Cardano                          0.54636                      -3.90133
# Dogecoin                         0.42135                      -1.34176
# TRON                             0.16633                       1.28985
# Chainlink                        0.38370                      -4.53587
# Toncoin                          0.43612                      -1.70249
# Polygon                          0.94470                       6.82663
# Polkadot                         0.17104                      -2.91795
# Avalanche                       -0.18092                      -2.96986
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          5.07802                      36.92283
# Ethereum                        10.96873                      35.66442
# Tether USDt                     -0.00186                       0.03317
# BNB                             -1.71587                      19.53796
# XRP                             -9.11630                      33.65413
# USDC                             0.02387                      -0.00365
# Solana                          38.74513                     154.08201
# Cardano                          5.02148                      49.79644
# Dogecoin                         4.65098                      30.01327
# TRON                            11.77682                      28.53825
# Chainlink                       19.92786                     107.73789
# Toncoin                          5.12690                      26.33727
# Polygon                         24.80816                      71.48005
# Polkadot                        14.58148                      48.74817
# Avalanche                       35.12380                      90.45955
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          38.31890                      25.93469
# Ethereum                         29.37957                      14.97197
# Tether USDt                       0.01466                       0.18548
# BNB                              15.99469                       3.45509
# XRP                              33.67892                       4.30263
# USDC                              0.00737                       0.02151
# Solana                          194.15323                     126.64012
# Cardano                          47.84575                      28.72930
# Dogecoin                         25.26493                       5.00434
# TRON                             32.09879                      42.35084
# Chainlink                       149.18401                     108.63097
# Toncoin                          29.11805                      64.83597
# Polygon                          70.61824                      34.70452
# Polkadot                         38.07132                      12.98733
# Avalanche                        87.35835                      43.45285

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin    quote.USD.percent_change_1h     0.27101
#            quote.USD.percent_change_24h   -0.69871
#            quote.USD.percent_change_7d     5.07802
#            quote.USD.percent_change_30d   36.92283
#            quote.USD.percent_change_60d   38.31890
#                                             ...
# Avalanche  quote.USD.percent_change_24h   -2.96986
#            quote.USD.percent_change_7d    35.12380
#            quote.USD.percent_change_30d   90.45955
#            quote.USD.percent_change_60d   87.35835
#            quote.USD.percent_change_90d   43.45285
# Length: 90, dtype: float64

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                          values
# name
# Bitcoin   quote.USD.percent_change_1h   0.27101
#           quote.USD.percent_change_24h -0.69871
#           quote.USD.percent_change_7d   5.07802
#           quote.USD.percent_change_30d 36.92283
#           quote.USD.percent_change_60d 38.31890
# ...                                         ...
# Avalanche quote.USD.percent_change_24h -2.96986
#           quote.USD.percent_change_7d  35.12380
#           quote.USD.percent_change_30d 90.45955
#           quote.USD.percent_change_60d 87.35835
#           quote.USD.percent_change_90d 43.45285
#
# [90 rows x 1 columns]

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#          name                       level_1   values
# 0     Bitcoin   quote.USD.percent_change_1h  0.27101
# 1     Bitcoin  quote.USD.percent_change_24h -0.69871
# 2     Bitcoin   quote.USD.percent_change_7d  5.07802
# 3     Bitcoin  quote.USD.percent_change_30d 36.92283
# 4     Bitcoin  quote.USD.percent_change_60d 38.31890
# ..        ...                           ...      ...
# 85  Avalanche  quote.USD.percent_change_24h -2.96986
# 86  Avalanche   quote.USD.percent_change_7d 35.12380
# 87  Avalanche  quote.USD.percent_change_30d 90.45955
# 88  Avalanche  quote.USD.percent_change_60d 87.35835
# 89  Avalanche  quote.USD.percent_change_90d 43.45285
#
# [90 rows x 3 columns]

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#          name                percent_change   values
# 0     Bitcoin   quote.USD.percent_change_1h  0.27101
# 1     Bitcoin  quote.USD.percent_change_24h -0.69871
# 2     Bitcoin   quote.USD.percent_change_7d  5.07802
# 3     Bitcoin  quote.USD.percent_change_30d 36.92283
# 4     Bitcoin  quote.USD.percent_change_60d 38.31890
# ..        ...                           ...      ...
# 85  Avalanche  quote.USD.percent_change_24h -2.96986
# 86  Avalanche   quote.USD.percent_change_7d 35.12380
# 87  Avalanche  quote.USD.percent_change_30d 90.45955
# 88  Avalanche  quote.USD.percent_change_60d 87.35835
# 89  Avalanche  quote.USD.percent_change_90d 43.45285
#
# [90 rows x 3 columns]

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#          name percent_change   values
# 0     Bitcoin             1h  0.27101
# 1     Bitcoin            24h -0.69871
# 2     Bitcoin             7d  5.07802
# 3     Bitcoin            30d 36.92283
# 4     Bitcoin            60d 38.31890
# ..        ...            ...      ...
# 85  Avalanche            24h -2.96986
# 86  Avalanche             7d 35.12380
# 87  Avalanche            30d 90.45955
# 88  Avalanche            60d 87.35835
# 89  Avalanche            90d 43.45285
#
# [90 rows x 3 columns]

# %% [markdown]
# # Visualizing Data

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values',hue='name',data=df7,kind='point')
